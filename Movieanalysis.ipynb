# %%
import pandas as pd

# %%
movies=pd.read_csv(r"C:\Users\raavi\Desktop\NIT\archive\movie.csv")

# %%
movies.head(20)
# Out:
#     movieId                                  title  \
# 0         1                       Toy Story (1995)
# 1         2                         Jumanji (1995)
# 2         3                Grumpier Old Men (1995)
# 3         4               Waiting to Exhale (1995)
# 4         5     Father of the Bride Part II (1995)
# 5         6                            Heat (1995)
# 6         7                         Sabrina (1995)
# 7         8                    Tom and Huck (1995)
# 8         9                    Sudden Death (1995)
# 9        10                       GoldenEye (1995)
# 10       11         American President, The (1995)
# 11       12     Dracula: Dead and Loving It (1995)
# 12       13                           Balto (1995)
# 13       14                           Nixon (1995)
# 14       15                Cutthroat Island (1995)
# 15       16                          Casino (1995)
# 16       17           Sense and Sensibility (1995)
# ...

# %%
ratings= pd.read_csv(r"C:\Users\raavi\Desktop\NIT\archive\rating.csv")
ratings
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.head(20)
# Out:
#     userId  movieId  rating            timestamp
# 0        1        2     3.5  2005-04-02 23:53:47
# 1        1       29     3.5  2005-04-02 23:31:16
# 2        1       32     3.5  2005-04-02 23:33:39
# 3        1       47     3.5  2005-04-02 23:32:07
# 4        1       50     3.5  2005-04-02 23:29:40
# 5        1      112     3.5  2004-09-10 03:09:00
# 6        1      151     4.0  2004-09-10 03:08:54
# 7        1      223     4.0  2005-04-02 23:46:13
# 8        1      253     4.0  2005-04-02 23:35:40
# 9        1      260     4.0  2005-04-02 23:33:46
# 10       1      293     4.0  2005-04-02 23:31:43
# 11       1      296     4.0  2005-04-02 23:32:47
# 12       1      318     4.0  2005-04-02 23:33:18
# 13       1      337     3.5  2004-09-10 03:08:29
# 14       1      367     3.5  2005-04-02 23:53:00
# 15       1      541     4.0  2005-04-02 23:30:03
# 16       1      589     3.5  2005-04-02 23:45:57
# 17       1      593     3.5  2005-04-02 23:31:01
# ...

# %%
tags =pd.read_csv(r"C:\Users\raavi\Desktop\NIT\archive\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.head(29)
# Out:
#     userId  movieId                                 tag            timestamp
# 0       18     4141                         Mark Waters  2009-04-24 18:19:40
# 1       65      208                           dark hero  2013-05-10 01:41:18
# 2       65      353                           dark hero  2013-05-10 01:41:19
# 3       65      521                       noir thriller  2013-05-10 01:39:43
# 4       65      592                           dark hero  2013-05-10 01:41:18
# 5       65      668                           bollywood  2013-05-10 01:37:56
# 6       65      898                    screwball comedy  2013-05-10 01:42:40
# 7       65     1248                       noir thriller  2013-05-10 01:39:43
# 8       65     1391                                mars  2013-05-10 01:40:55
# 9       65     1617                            neo-noir  2013-05-10 01:43:37
# 10      65     1694                               jesus  2013-05-10 01:38:45
# ...

# %%
del tags["timestamp"]
del ratings["timestamp"]

# %%
T= tags.head(29)
R = ratings.head(78)
print(T)
print(R)
# Out:
#     userId  movieId                                 tag
# 0       18     4141                         Mark Waters
# 1       65      208                           dark hero
# 2       65      353                           dark hero
# 3       65      521                       noir thriller
# 4       65      592                           dark hero
# 5       65      668                           bollywood
# 6       65      898                    screwball comedy
# 7       65     1248                       noir thriller
# 8       65     1391                                mars
# 9       65     1617                            neo-noir
# 10      65     1694                               jesus
# 11      65     1783                       noir thriller
# 12      65     2022                               jesus
# 13      65     2193                              dragon
# 14      65     2353                   conspiracy theory
# 15      65     2662                                mars
# ...

# %%
s1= tags.iloc[3]
print(s1)
# Out:
# userId                65
# movieId              521
# tag        noir thriller
# Name: 3, dtype: object

# %%
s1.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
s1[['userId','movieId' ]]
# Out:
# userId      65
# movieId    521
# Name: 3, dtype: object

# %%
s1[['userId','movieId' ]].T
# Out:
# userId      65
# movieId    521
# Name: 3, dtype: object

# %%
'ratings' in s1
# Out:
# False

# %%
'userId' in s1
# Out:
# True

# %%
s1.name
# Out:
# 3

# %%
s1=s1.rename('Namsthe')
s1
# Out:
# userId                65
# movieId              521
# tag        noir thriller
# Name: Namsthe, dtype: object

# %%
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[2:19:2]
# Out:
#     userId  movieId                tag
# 2       65      353          dark hero
# 4       65      592          dark hero
# 6       65      898   screwball comedy
# 8       65     1391               mars
# 10      65     1694              jesus
# 12      65     2022              jesus
# 14      65     2353  conspiracy theory
# 16      65     2726      noir thriller
# 18      65     3052              jesus

# %%
tags.iloc[[2,19,298769]]
# Out:
#         userId  movieId             tag
# 2           65      353       dark hero
# 19          65     5135       bollywood
# 298769   88738     6197  mental illness

# %%
tags.describe().transpose()
# Out:
#             count          mean           std   min      25%      50%  \
# userId   465564.0  68712.354263  41877.674053  18.0  28780.0  70201.0
# movieId  465564.0  32627.762920  36080.241157   1.0   2571.0   7373.0
#
#               75%       max
# userId   107322.0  138472.0
# movieId   62235.0  131258.0

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe().transpose()
# Out:
#               count          mean           std  min      25%      50%  \
# userId   20000263.0  69045.872583  40038.626653  1.0  34395.0  69141.0
# movieId  20000263.0   9041.567330  19789.477445  1.0    902.0   2167.0
# rating   20000263.0      3.525529      1.051989  0.5      3.0      3.5
#
#               75%       max
# userId   103637.0  138493.0
# movieId    4770.0  131262.0
# rating        4.0       5.0

# %%
ratings.mean().transpose()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
ratings['movieId'].mean() # It is used to get the mean or any statistics for particular column
# Out:
# np.float64(9041.567330339605)

# %%
ratings['rating'].min()
# Out:
# np.float64(0.5)

# %%
ratings['rating'].std()
# Out:
# np.float64(1.0519889192942418)

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
ratings.userId>1
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258     True
# 20000259     True
# 20000260     True
# 20000261     True
# 20000262     True
# Name: userId, Length: 20000263, dtype: bool

# %%
ratings[ratings.userId>1]
# Out:
#           userId  movieId  rating
# 175            2        3     4.0
# 176            2       62     5.0
# 177            2       70     5.0
# 178            2      110     4.0
# 179            2      242     3.0
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000088 rows x 3 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
ratings.isnull()
# Out:
#           userId  movieId  rating
# 0          False    False   False
# 1          False    False   False
# 2          False    False   False
# 3          False    False   False
# 4          False    False   False
# ...          ...      ...     ...
# 20000258   False    False   False
# 20000259   False    False   False
# 20000260   False    False   False
# 20000261   False    False   False
# 20000262   False    False   False
#
# [20000263 rows x 3 columns]

# %%
ratings.isnull().sum()
# Out:
# userId     0
# movieId    0
# rating     0
# dtype: int64

# %%
filter2 = ratings['rating'] > 0
filter2.all()
# Out:
# np.True_

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %%
movies.isnull().all()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
tags=tags.dropna()
print(tags)
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465548 rows x 3 columns]

# %%
tags.isnull().sum()
# Out:
# userId     0
# movieId    0
# tag        0
# dtype: int64

# %%
tags.shape
# Out:
# (465548, 3)

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt # Visualization
import seaborn as sns  # Stats visualization, advanced visualization,

plt.rcParams['figure.figsize']=6,2 #rcParam  param comes from ply library where fig size width = 6 and height =2
import warnings
warnings.filterwarnings('ignore') # whenever OS update Ignore the as error using ignore warning message

# %%
vs=sns.distplot(tags["movieId"])

# %%
vs=plt.hist(tags["movieId"])

# %%
vs=plt.boxplot(tags["movieId"])

# %%
vs=sns.boxplot(tags["movieId"])

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
vs=sns.boxplot(tags[["movieId", "userId"]])

# %%
tags.movieId.unique()
# Out:
# array([  4141,    208,    353, ..., 113539, 115373,   1495],
#       shape=(19545,))

# %%
tags.movieId.nunique()
# Out:
# 19545

# %%
tags[tags.movieId=='4141']
# Out:
# Empty DataFrame
# Columns: [userId, movieId, tag]
# Index: []

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 tag_counts[:10].plot(kind='bar', figsize=(10,5))
#
# NameError: name 'tag_counts' is not defined
